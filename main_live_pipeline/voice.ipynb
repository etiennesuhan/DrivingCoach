# %%
import pandas as pd

# %%
DATABASE_BAD = "sqlite:///../data/test.db"
QUERY = "SELECT * FROM telemetry_samples ORDER BY id"

# %%
df = pd.read_sql(QUERY, DATABASE_BAD)
print(df.to_markdown())
# Out:
# |     |   id |   race_id | timestamp_utc            |   packet_length | packet_schema   | raw                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
# ...
